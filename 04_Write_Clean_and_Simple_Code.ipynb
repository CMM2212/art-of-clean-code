# %% [markdown]
# Code is read 10x as often as it is written so spend more time making it clean

# %% [markdown]
# # Principles of Clean Code

# %% [markdown]
# ## 1: Think about the big picture
#
# Decide on what features you need.
#
# * Do you need all the seperate files and modulesor can you consolidate to reduce interdependncy
# * can you divide larg files into simpler ones.
# * Can existing libraries get rid of code?
# * Can you cache results to reduce computations
# * can you remove premature optomizations that didn't help

# %% [markdown]
# ## 2: Stand on the shoulders of giants
#
# Use libraries

# %% [markdown]
# ## 3: Code for people, not machines
#
# Use meaningful variable names

# %% [markdown]
# ## 4: Use the right names
#
# 1. choose descriptive names
# 2. choose unambiguous names
# 3. choose pronouncable names
# 4. used name constants not magic numbers

# %% [markdown]
# # 5: Adhere to standards and be consistent
#
# Example: PEP8 for Python

# %% [markdown]
# ## 6: Use comments

# %% [markdown]
# ## 7: Avoid unecessary comments

# %% [markdown]
# ## 8 Principle of least surprise
#
# should behave in the way the user expects

# %% [markdown]
# ## 9: DRY Don't repeat yourself

# %% [markdown]
# ## 10: Single Responsibility Principle
#
# better use small functions than one big function
#
# functions should only do one thing

# %% [markdown]
# ## 11: TEst

# %% [markdown]
# ## 12: Small is beautiful

# %% [markdown]
# ## 13: Law of demeter
#
# minimize dependencies of your code objects
#
# Only call your own methods or methods of adjacent objects. Dont' call methods of adjacent objects' adjecent object
#
# A.A_Method, A.B.B_Method, NOT A.B.C.C_Method
#
# Only talk to your immediate friends. Don't chain

# %% [markdown]
# ## 14: You ain't gonna need it
#
# Only write code you're 100% sure you'll need
#
# Always go for low-hanging fruit first

# %% [markdown]
# ## 15: Don't use too many levels of indentation

# %% [markdown]
# ## 16: Use Metrics

# %% [markdown]
# ## 17: Boy scout rule and refactoring
#
# Leave the code cleaner than when you found it.
