# %% [markdown]
# The majority of effects (80%) come from a minority of causes (20%).

# %% [markdown]
# # 80/20 Code
#
# 20% of code is executed 80% of the time. It's best to focus on that 20% of code and not get distracted by the rest that isn't used much.
