# %% [markdown]
# # Project Life Cycle

# %% [markdown]
# ## Planning
#
# A strictly defined set of required features to deliver to the end user.

# %% [markdown]
# ## Defining
#
# Formalizing the planning

# %% [markdown]
# ## Designing
#
# How the software product will look and how it's built.

# %% [markdown]
# ## Building
#
# Converting the design to code

# %% [markdown]
# ## Testing
#
# Unit tests

# %% [markdown]
# ## Deployment
#
# Publishing the app
